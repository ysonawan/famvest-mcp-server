# %% [raw]
# Create MCP Server

# %%
from fastmcp import FastMCP

mcp = FastMCP("My MCP Server")

# %% [markdown]
# Add a Tool

# %%
@mcp.tool
def greet(name: str) -> str:
    return f"Hello, {name}!"

# %% [markdown]
# Run the server

# %%
if __name__ == "__main__":
    mcp.run()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 2
#       1 if __name__ == "__main__":
# ----> 2     mcp.run()
#
# File ~/work/workspaces/mcp/fastmcp-course/.venv/lib/python3.14/site-packages/fastmcp/server/server.py:637, in FastMCP.run(self, transport, show_banner, **transport_kwargs)
#     625 def run(
#     626     self,
#     627     transport: Transport | None = None,
#     628     show_banner: bool = True,
#     629     **transport_kwargs: Any,
#     630 ) -> None:
#     631     """Run the FastMCP server. Note this is a synchronous function.
#     632
#     633     Args:
#     634         transport: Transport protocol to use ("stdio", "sse", or "streamable-http")
#     635     """
# --> 637     anyio.run(
#     638         partial(
#     639             self.run_async,
#     640             transport,
#     641             show_banner=show_banner,
# ...
